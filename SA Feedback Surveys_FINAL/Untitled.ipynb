# %%
import glob
import pandas as pd

df2016 = [pd.read_csv(f) for f in glob.glob('./2016/*.csv')]

# %%
df2016
# Out:
# [           Timestamp  \
#  0   8/5/2016 1:39:41
#  1   8/5/2016 1:40:47
#  2   8/5/2016 1:40:50
#  3   8/5/2016 1:42:44
#  4   8/5/2016 1:45:13
#  5   8/5/2016 1:45:39
#  6   8/5/2016 1:49:21
#  7   8/8/2016 1:30:34
#  8   8/8/2016 1:33:45
#  9   8/8/2016 1:49:29
#  10  8/8/2016 1:51:00
#
#      How would you rate your overall satisfaction with the Summer Academy this week?  \
#  0                                                   3
#  1                                                   4
#  2                                                   4
#  3                                                   4
#  4                                                   5
#  5                                                   4
#  6                                                   4
#  7                                                   5
#  8                                                   5
#  9                                                   5
# ...
